# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
import os
import warnings
warnings.filterwarnings("ignore")

# %%
train_dir = r"C:\Users\Soft\Desktop\Py\Docs\Covid19-dataset\train"
test_dir = r"C:\Users\Soft\Desktop\Py\Docs\Covid19-dataset\test"

# %%
img_width, img_height = 512, 512

# %%
batch_size = 32

# %%
train_dataset = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
test_dataset = ImageDataGenerator(rescale=1./255)

# %%
X_train = train_dataset.flow_from_directory(
    train_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical"
)
# Out:
# Found 251 images belonging to 3 classes.

# %%
X_test = test_dataset.flow_from_directory(
    test_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical"
)
# Out:
# Found 66 images belonging to 3 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(img_width, img_height, 3)),
    MaxPool2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPool2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPool2D((2, 2)),
    Conv2D(128, (3, 3), activation="relu"),
    MaxPool2D((2, 2)),
    Flatten(),
    Dense(512, activation="relu"),
    Dense(256, activation="relu"),
    Dense(3, activation="softmax")
])

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(X_train, epochs=30, validation_data=X_test)
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\Soft\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Soft\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 8/8 [==============================] - 86s 10s/step - loss: 1.5451 - accuracy: 0.4263 - val_loss: 1.0823 - val_accuracy: 0.3182
# Epoch 2/30
# 8/8 [==============================] - 71s 8s/step - loss: 0.7713 - accuracy: 0.6215 - val_loss: 1.6533 - val_accuracy: 0.3485
# Epoch 3/30
# 8/8 [==============================] - 77s 9s/step - loss: 0.6629 - accuracy: 0.7012 - val_loss: 0.9586 - val_accuracy: 0.6667
# Epoch 4/30
# 8/8 [==============================] - 80s 10s/step - loss: 0.5636 - accuracy: 0.7849 - val_loss: 0.8529 - val_accuracy: 0.6515
# Epoch 5/30
# 8/8 [==============================] - 81s 10s/step - loss: 0.5197 - accuracy: 0.7729 - val_loss: 0.9151 - val_accuracy: 0.7121
# Epoch 6/30
# 8/8 [==============================] - 82s 10s/step - loss: 0.5316 - accuracy: 0.7729 - val_loss: 0.7926 - val_accuracy: 0.7424
# Epoch 7/30
# 8/8 [==============================] - 81s 10s/step - loss: 0.4707 - accuracy: 0.8207 - val_loss: 0.6717 - val_accuracy: 0.7576
# Epoch 8/30
# 8/8 [==============================] - 82s 10s/step - loss: 0.4330 - accuracy: 0.8327 - val_loss: 0.9718 - val_accuracy: 0.6818
# Epoch 9/30
# 8/8 [==============================] - 79s 9s/step - loss: 0.4232 - accuracy: 0.8207 - val_loss: 0.9848 - val_accuracy: 0.6364
# Epoch 10/30
# 8/8 [==============================] - 70s 8s/step - loss: 0.4891 - accuracy: 0.8566 - val_loss: 1.0188 - val_accuracy: 0.6212
# Epoch 11/30
# 8/8 [==============================] - 60s 7s/step - loss: 0.4333 - accuracy: 0.8207 - val_loss: 0.6148 - val_accuracy: 0.7273
# Epoch 12/30
# 8/8 [==============================] - 59s 7s/step - loss: 0.4207 - accuracy: 0.8526 - val_loss: 0.7421 - val_accuracy: 0.7424
# Epoch 13/30
# 8/8 [==============================] - 59s 7s/step - loss: 0.3680 - accuracy: 0.8526 - val_loss: 0.8032 - val_accuracy: 0.7121
# Epoch 14/30
# 8/8 [==============================] - 60s 7s/step - loss: 0.3119 - accuracy: 0.8884 - val_loss: 0.6116 - val_accuracy: 0.7576
# Epoch 15/30
# 8/8 [==============================] - 61s 7s/step - loss: 0.4578 - accuracy: 0.8446 - val_loss: 0.8753 - val_accuracy: 0.6061
# Epoch 16/30
# 8/8 [==============================] - 59s 7s/step - loss: 0.3919 - accuracy: 0.8406 - val_loss: 0.6715 - val_accuracy: 0.7121
# Epoch 17/30
# 8/8 [==============================] - 61s 7s/step - loss: 0.3570 - accuracy: 0.8805 - val_loss: 0.6327 - val_accuracy: 0.7424
# Epoch 18/30
# 8/8 [==============================] - 68s 9s/step - loss: 0.3204 - accuracy: 0.8725 - val_loss: 0.5406 - val_accuracy: 0.7273
# Epoch 19/30
# 8/8 [==============================] - 69s 8s/step - loss: 0.3894 - accuracy: 0.8526 - val_loss: 0.7432 - val_accuracy: 0.6818
# Epoch 20/30
# 8/8 [==============================] - 59s 7s/step - loss: 0.3672 - accuracy: 0.8685 - val_loss: 0.4449 - val_accuracy: 0.8030
# Epoch 21/30
# 8/8 [==============================] - 66s 8s/step - loss: 0.3138 - accuracy: 0.8884 - val_loss: 0.3835 - val_accuracy: 0.8182
# Epoch 22/30
# 8/8 [==============================] - 69s 8s/step - loss: 0.3400 - accuracy: 0.8606 - val_loss: 0.5850 - val_accuracy: 0.6818
# Epoch 23/30
# 8/8 [==============================] - 80s 10s/step - loss: 0.2733 - accuracy: 0.9004 - val_loss: 0.4801 - val_accuracy: 0.8182
# Epoch 24/30
# 8/8 [==============================] - 58s 7s/step - loss: 0.2397 - accuracy: 0.9203 - val_loss: 0.4612 - val_accuracy: 0.7273
# Epoch 25/30
# 8/8 [==============================] - 59s 7s/step - loss: 0.2610 - accuracy: 0.8845 - val_loss: 0.3712 - val_accuracy: 0.8485
# Epoch 26/30
# 8/8 [==============================] - 58s 7s/step - loss: 0.2434 - accuracy: 0.9004 - val_loss: 0.6353 - val_accuracy: 0.6515
# Epoch 27/30
# 8/8 [==============================] - 58s 7s/step - loss: 0.2286 - accuracy: 0.9203 - val_loss: 0.6172 - val_accuracy: 0.7576
# Epoch 28/30
# 8/8 [==============================] - 59s 7s/step - loss: 0.1996 - accuracy: 0.9044 - val_loss: 0.4782 - val_accuracy: 0.7879
# Epoch 29/30
# 8/8 [==============================] - 60s 7s/step - loss: 0.2461 - accuracy: 0.9124 - val_loss: 0.7606 - val_accuracy: 0.7879
# Epoch 30/30
# 8/8 [==============================] - 58s 7s/step - loss: 0.3049 - accuracy: 0.8805 - val_loss: 0.5547 - val_accuracy: 0.7121

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train", "Validation"])
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])
plt.show()

# %%
class_labels = X_train.class_indices

# %%
class_names = {value: key for key, value in class_labels.items()}
print("Class Names:", class_names)
# Out:
# Class Names: {0: 'Covid', 1: 'Normal', 2: 'Viral Pneumonia'}

# %%
from tensorflow.keras.preprocessing import image

# %%
img_path = r"C:\Users\Soft\Desktop\Py\Docs\test_img.jpeg"

# %%
img = image.load_img(img_path, target_size=(img_width, img_height))

# %%
img_arr = image.img_to_array(img)

# %%
img_arr = np.expand_dims(img_arr, axis=0)

# %%
img_arr = img_arr / 255.0

# %%
pred = model.predict(img_arr)
# Out:
# 1/1 [==============================] - 0s 175ms/step

# %%
pred_class = np.argmax(pred)

# %%
class_names[pred_class]
# Out:
# 'Covid'
